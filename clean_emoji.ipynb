# %%
# !pip install emoji
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.9/240.9 KB 4.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for emoji: filename=emoji-2.2.0-py3-none-any.whl size=234926 sha256=987fb2cea838f10fdad455a64536efe4b8977c763230348e8b7fcda156ab1cf6
#   Stored in directory: /root/.cache/pip/wheels/9a/b8/0f/f580817231cbf59f6ade9fd132ff60ada1de9f7dc85521f857
# Successfully built emoji
# ...

# %%
import pandas as pd
import numpy as np
import re
import emoji

# %%
data=pd.read_csv("/content/corrected_bank_translated.csv.csv")

# %%
data
# Out:
#                                                comments   years  \
# 0     Sizin Xaçmaz filialınız rus pulunu özü satır, ...  2017.0
# 1     I have been dealing with this bank approximate...  2022.0
# 2     No support on weekend. I made payment through ...  2021.0
# 3                           Staff is so polite and cute  2019.0
# 4                       Harikasınız, super güzel teklif  2020.0
# ...                                                 ...     ...
# 1102                             Service level is good.  2019.0
# 1103                                                NaN     NaN
# 1104  we called the hotline and they were keeping to...  2021.0
# 1105                                      Kind people\t  2022.0
# 1106                         Bank that turns off ATMs\t  2022.0
#
#                                              translated
# 0     Your Khachmaz branch sells Russian money itsel...
# 1     I have been dealing with this bank approximate...
# ...

# %%
data.dropna(how='all', axis=0, inplace=True)

# %%
data.isnull().sum()
# Out:
# comments      0
# years         0
# translated    0
# dtype: int64

# %%
data.reset_index(drop=True, inplace=True)

# %%
data.tail()
# Out:
#                                               comments   years  \
# 995  They serve the people well in a beautiful and ...  2020.0
# 996                             Service level is good.  2019.0
# 997  we called the hotline and they were keeping to...  2021.0
# 998                                      Kind people\t  2022.0
# 999                         Bank that turns off ATMs\t  2022.0
#
#                                             translated
# 995  They serve the people well in a beautiful and ...
# 996                             Service level is good.
# 997  we called the hotline and they were keeping to...
# 998                                      Kind people\t
# 999                         Bank that turns off ATMs\t

# %%
data=data.replace("(\t)", "", regex=True)

# %%
data.head()
# Out:
#                                             comments   years  \
# 0  Sizin Xaçmaz filialınız rus pulunu özü satır, ...  2017.0
# 1  I have been dealing with this bank approximate...  2022.0
# 2  No support on weekend. I made payment through ...  2021.0
# 3                        Staff is so polite and cute  2019.0
# 4                    Harikasınız, super güzel teklif  2020.0
#
#                                           translated
# 0  Your Khachmaz branch sells Russian money itsel...
# 1  I have been dealing with this bank approximate...
# 2  No support on weekend. I made payment through ...
# 3                        Staff is so polite and cute
# 4                  You are amazing, super nice offer

# %%
data['translated']= data['translated'].apply(lambda x: emoji.replace_emoji(x, ''))

# %%
data
# Out:
#                                               comments   years  \
# 0    Sizin Xaçmaz filialınız rus pulunu özü satır, ...  2017.0
# 1    I have been dealing with this bank approximate...  2022.0
# 2    No support on weekend. I made payment through ...  2021.0
# 3                          Staff is so polite and cute  2019.0
# 4                      Harikasınız, super güzel teklif  2020.0
# ..                                                 ...     ...
# 995  They serve the people well in a beautiful and ...  2020.0
# 996                             Service level is good.  2019.0
# 997  we called the hotline and they were keeping to...  2021.0
# 998                                        Kind people  2022.0
# 999                           Bank that turns off ATMs  2022.0
#
#                                             translated
# 0    Your Khachmaz branch sells Russian money itsel...
# 1    I have been dealing with this bank approximate...
# ...

# %%
#df=pd.DataFrame({'comments':np.nan, 'years':np.nan, 'translated': np.nan}, index=[0,1])

# %%
#datam = pd.concat([data, df]).reset_index(drop = True)

# %%
#datam.loc[998, 'comments']='Kind People'

# %%
#datam.loc[998, 'comments']=float(2022)
#datam.loc[998, 'comments']='Kind people'

# %%
#datam.loc[999, 'comments']='Bank that turns off ATMs in the evening'
##datam.loc[999, 'comments']=float(2022)
#datam.loc[999, 'comments']='Bank that turns off ATMs'

# %%
datam
# Out:
#                                               comments   years  \
# 0    Sizin Xaçmaz filialınız rus pulunu özü satır, ...  2017.0
# 1    I have been dealing with this bank approximate...  2022.0
# 2    No support on weekend. I made payment through ...  2021.0
# 3                          Staff is so polite and cute  2019.0
# 4                      Harikasınız, super güzel teklif  2020.0
# ..                                                 ...     ...
# 995  They serve the people well in a beautiful and ...  2020.0
# 996                             Service level is good.  2019.0
# 997  we called the hotline and they were keeping to...  2021.0
# 998                                        Kind people  2022.0
# 999                           Bank that turns off ATMs  2022.0
#
#                                             translated
# 0    Your Khachmaz branch sells Russian money itsel...
# 1    I have been dealing with this bank approximate...
# ...

# %%
data.shape
# Out:
# (1000, 3)

# %%
#data.years=data.years.astype(float)

# %%
datam.dtypes
# Out:
# comments       object
# years         float64
# translated     object
# dtype: object

# %%
data.years=pd.to_datetime(data.years, format='%Y')

# %%
data
# Out:
#                                               comments      years  \
# 0    Sizin Xaçmaz filialınız rus pulunu özü satır, ... 2017-01-01
# 1    I have been dealing with this bank approximate... 2022-01-01
# 2    No support on weekend. I made payment through ... 2021-01-01
# 3                          Staff is so polite and cute 2019-01-01
# 4                      Harikasınız, super güzel teklif 2020-01-01
# ..                                                 ...        ...
# 995  They serve the people well in a beautiful and ... 2020-01-01
# 996                             Service level is good. 2019-01-01
# 997  we called the hotline and they were keeping to... 2021-01-01
# 998                                        Kind people 2022-01-01
# 999                           Bank that turns off ATMs 2022-01-01
#
#                                             translated
# 0    Your Khachmaz branch sells Russian money itsel...
# 1    I have been dealing with this bank approximate...
# ...

# %%
#data.years=data.years.dt.to_period('Y')

# %%
data.to_csv("BANK_REVIEWS_DATASET_year.csv")

# %%
data.dtypes
# Out:
# comments              object
# years         datetime64[ns]
# translated            object
# dtype: object
